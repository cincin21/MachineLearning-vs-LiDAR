# %% [markdown]
# ## 01. XGBoost Tuning for Aerial LiDAR Data Classification
#
# <br>
#
# __LiDAR__, which stands for Light Detection and Ranging, is a remote sensing method that uses light in the form of a pulsed laser to measure ranges to the Earth. These light pulses—combined with other data recorded by the airborne system— generate precise, three-dimensional information about the shape of the Earth and its surface characteristics.
#
# The aim of the thesis is to choose and optimize a machine learning algorithm to perform classification of aerial laser skanning data into classes using avaliable features from __*.LAS__ format data.
#
# For the purpose of the project the data was firstly converted to __*.csv__ format with __ArcGIS PRO 2.1.1__ software.
#
# <img src="img/LAS_dataset.png" width="80%">
# Source: http://pro.arcgis.com/en/pro-app/help/data/las-dataset/GUID-C323587E-81F2-4823-B2E4-2331445BF5D1-web.png
#
#
# <br>
#
# ### Table of Contents
#
#     1.Train / test dataset
#
#         1.1 Data analysis
#         1.2 Data sampling
#         1.3 XGBoost - default
#         1.4 XGBoost - tuning
#
#     2.Test dataset
#
#         2.1 Data analysis
#         2.2 XGBoost - default
#         2.3 XGBoost - tuned

# %% [markdown]
# ## 1.Train / test dataset
# ### 1.1 Data analysis
#
# The dataset composes of two areas - one for training / testing and one for final independent accuracy testing. They all cover a selected area of Peplin municipality.
#
#
# <img src="img/Zakres1_2_2d.jpg" width="80%">
#
#
# First subject consists of 268 523 LiDAR points located over 41 379 square meters.
#
#
# <img src='img/Zakres1_2d.jpg' width="80%">
# <img src='img/Zakres1_3d.jpg' width="80%">
#
#
# In the next steps we will read and analyze the __Train_Test_Area.csv__ data

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
tt_area = pd.read_csv('data/01.Train_Test_Area.csv', header=0, delimiter=' ')
tt_area.head(10)
# Out:
#               X            Y          Z    R    G    B  PointSourceId  \
# 0  484179.43750  676279.6875  49.340000  124  124  112          101.0
# 1  484179.31250  676280.0000  49.320000  124  125  115          101.0
# 2  484178.81250  676280.0625  49.310001  123  124  113          101.0
# 3  484178.31250  676280.1250  49.340000  122  122  112          101.0
# 4  484177.81250  676280.1875  49.320000  122  122  112          101.0
# 5  484177.31250  676280.1875  49.320000  125  125  115          101.0
# 6  484176.84375  676280.2500  49.310001  124  124  115          101.0
# 7  484176.31250  676280.2500  49.340000  125  125  117          101.0
# 8  484179.12500  676280.3750  49.310001  124  126  115          101.0
# 9  484178.65625  676280.3750  49.320000  128  129  119          101.0
#
#    ScanAngleRank  ScanDirectionFlag  NumberOfReturns  ReturnNumber  Intensity  \
# 0          -25.0                1.0              1.0           1.0       64.0
# 1          -25.0                1.0              1.0           1.0       60.0
# 2          -25.0                1.0              1.0           1.0       62.0
# 3          -25.0                1.0              1.0           1.0       64.0
# 4          -25.0                1.0              1.0           1.0       70.0
# 5          -25.0                1.0              1.0           1.0       63.0
# 6          -25.0                1.0              1.0           1.0       63.0
# 7          -25.0                1.0              1.0           1.0       57.0
# 8          -25.0                1.0              1.0           1.0       54.0
# 9          -25.0                1.0              1.0           1.0       58.0
#
#    Classification
# 0            12.0
# 1            12.0
# 2            12.0
# 3            12.0
# 4            12.0
# 5            12.0
# 6            12.0
# 7            12.0
# 8            12.0
# 9            12.0

# %% [markdown]
# __LiDAR__ per-point data attriubtes definition:
#
# __X__,__Y__ - The planimetric ground location of the point,
#
# __Z__ - The elevation of the point,
#
# __R__,__G__,__B__ - Additive color model values,
#
# __PointSourceId__ - A unique identifier to reference this point back to a collection source,
#
# __ScanAngleRank__ - Angle at which the laser point was output from the laser system including the roll of the aircraft,
#
# __ScanDirectionFlag__ - Direction the laser scanning mirror was traveling at the time of the output laser pulse,
#
# __NumberOfReturns__ - Number of returns detected for a given transmitted pulse,
#
# __Intensity__ - The laser pulse return intensity at the sensor,
#
# __Classification__ - Surface attribute assigned to this point such as ground, vegetation.

# %%
tt_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268523 entries, 0 to 268522
# Data columns (total 13 columns):
# X                    268523 non-null float64
# Y                    268523 non-null float64
# Z                    268523 non-null float64
# R                    268523 non-null int64
# G                    268523 non-null int64
# B                    268523 non-null int64
# PointSourceId        268523 non-null float64
# ScanAngleRank        268523 non-null float64
# ScanDirectionFlag    268523 non-null float64
# NumberOfReturns      268523 non-null float64
# ReturnNumber         268523 non-null float64
# Intensity            268523 non-null float64
# Classification       268523 non-null float64
# dtypes: float64(10), int64(3)
# memory usage: 26.6 MB

# %%
tt_area.isnull().sum()
# Out:
# X                    0
# Y                    0
# Z                    0
# R                    0
# G                    0
# B                    0
# PointSourceId        0
# ScanAngleRank        0
# ScanDirectionFlag    0
# NumberOfReturns      0
# ReturnNumber         0
# Intensity            0
# Classification       0
# dtype: int64

# %% [markdown]
# We can see that there are only numerical features and that there are no null values within all data, so we can proceed with further analysis.

# %%
tt_area.nunique()
# Out:
# X                    10099
# Y                     3056
# Z                     2856
# R                      233
# G                      225
# B                      228
# PointSourceId            2
# ScanAngleRank           26
# ScanDirectionFlag        1
# NumberOfReturns          5
# ReturnNumber             5
# Intensity              205
# Classification           8
# dtype: int64

# %%
tt_area.describe()
# Out:
#                    X              Y              Z              R  \
# count  268523.000000  268523.000000  268523.000000  268523.000000
# mean   484341.568816  676317.380434      54.626213     109.940996
# std        86.110618      41.725397       3.993748      39.911418
# min    484176.312500  676222.937500      48.880001      23.000000
# 25%    484262.687500  676284.937500      51.970001      83.000000
# 50%    484350.781250  676317.500000      55.029999     113.000000
# 75%    484416.625000  676349.625000      55.770000     133.000000
# max    484499.250000  676414.187500      78.730003     255.000000
#
#                    G              B  PointSourceId  ScanAngleRank  \
# count  268523.000000  268523.000000  268523.000000  268523.000000
# mean      113.993326      99.756259     101.999289      -4.039419
# std        33.695346      31.141255       0.026661       6.361055
# min        27.000000      28.000000     101.000000     -25.000000
# 25%        95.000000      81.000000     102.000000     -10.000000
# 50%       117.000000     100.000000     102.000000      -3.000000
# 75%       131.000000     113.000000     102.000000       2.000000
# max       255.000000     255.000000     102.000000       8.000000
#
#        ScanDirectionFlag  NumberOfReturns   ReturnNumber      Intensity  \
# count           268523.0    268523.000000  268523.000000  268523.000000
# mean                 1.0         1.108453       1.054223      78.284032
# std                  0.0         0.375321       0.256920      27.867723
# min                  1.0         1.000000       1.000000       8.000000
# 25%                  1.0         1.000000       1.000000      66.000000
# 50%                  1.0         1.000000       1.000000      79.000000
# 75%                  1.0         1.000000       1.000000      94.000000
# max                  1.0         5.000000       5.000000    1011.000000
#
#        Classification
# count   268523.000000
# mean         2.286460
# std          1.117257
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         12.000000

# %% [markdown]
# Next we will invest feature importance for further predictions.
#
# Because __'PointSourceId'__ and __'ScanDirectionFlag'__ columns consists with only 1 value we can assuredly delete them.
#
# Another aspect are __'X'__ and __'Y'__ coordinates that are values differrent for each point and have no correlation with different spatial areas and should also be deleted.
#
# We will use __Univariate Selection__ to confirm our predictions.

# %%
np.set_printoptions(precision=3)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = tt_area.iloc[:,0:12]
y = tt_area.iloc[:,12]
X.head(5)
# Out:
#              X            Y          Z    R    G    B  PointSourceId  \
# 0  484179.4375  676279.6875  49.340000  124  124  112          101.0
# 1  484179.3125  676280.0000  49.320000  124  125  115          101.0
# 2  484178.8125  676280.0625  49.310001  123  124  113          101.0
# 3  484178.3125  676280.1250  49.340000  122  122  112          101.0
# 4  484177.8125  676280.1875  49.320000  122  122  112          101.0
#
#    ScanAngleRank  ScanDirectionFlag  NumberOfReturns  ReturnNumber  Intensity
# 0          -25.0                1.0              1.0           1.0       64.0
# 1          -25.0                1.0              1.0           1.0       60.0
# 2          -25.0                1.0              1.0           1.0       62.0
# 3          -25.0                1.0              1.0           1.0       64.0
# 4          -25.0                1.0              1.0           1.0       70.0

# %%
X['ScanAngleRank'] = X['ScanAngleRank'].abs() # positive vaules required for Univariate Selection
X
# Out:
#                    X            Y          Z    R    G    B  PointSourceId  \
# 0       484179.43750  676279.6875  49.340000  124  124  112          101.0
# 1       484179.31250  676280.0000  49.320000  124  125  115          101.0
# 2       484178.81250  676280.0625  49.310001  123  124  113          101.0
# 3       484178.31250  676280.1250  49.340000  122  122  112          101.0
# 4       484177.81250  676280.1875  49.320000  122  122  112          101.0
# 5       484177.31250  676280.1875  49.320000  125  125  115          101.0
# 6       484176.84375  676280.2500  49.310001  124  124  115          101.0
# 7       484176.31250  676280.2500  49.340000  125  125  117          101.0
# 8       484179.12500  676280.3750  49.310001  124  126  115          101.0
# 9       484178.65625  676280.3750  49.320000  128  129  119          101.0
# 10      484178.12500  676280.4375  49.310001  128  128  120          101.0
# 11      484177.65625  676280.5000  49.320000  125  125  117          101.0
# 12      484177.12500  676280.5000  49.330002  122  122  114          101.0
# 13      484176.65625  676280.5625  49.340000  128  125  118          101.0
# 14      484179.56250  676280.6875  49.299999  112  114  103          101.0
# 15      484179.03125  676280.7500  49.299999  120  122  111          101.0
# 16      484178.56250  676280.7500  49.310001  126  128  117          101.0
# 17      484178.03125  676280.8125  49.320000  130  130  122          101.0
# 18      484177.56250  676280.8750  49.320000  126  126  118          101.0
# 19      484177.03125  676280.8750  49.320000  125  125  117          101.0
# 20      484176.56250  676280.9375  49.320000  122  119  112          101.0
# 21      484179.43750  676281.1250  49.299999  109  110  102          101.0
# 22      484178.90625  676281.1875  49.299999  122  124  113          101.0
# 23      484178.43750  676281.1875  49.299999  121  122  114          101.0
# 24      484177.93750  676281.2500  49.299999  121  121  113          101.0
# 25      484177.43750  676281.3125  49.310001  122  122  114          101.0
# 26      484176.93750  676281.3125  49.320000  119  119  111          101.0
# 27      484179.37500  676281.5000  49.279999  123  124  115          101.0
# 28      484178.84375  676281.5625  49.299999  119  121  110          101.0
# 29      484178.37500  676281.5625  49.310001  116  118  108          101.0
# ...              ...          ...        ...  ...  ...  ...            ...
# 268493  484447.43750  676334.7500  73.180000   71   80   72          102.0
# 268494  484448.65625  676334.9375  71.800003   67   78   70          102.0
# 268495  484449.06250  676335.0000  71.500000   69   80   73          102.0
# 268496  484450.00000  676334.8125  75.169998   57   66   63          102.0
# 268497  484450.37500  676334.8125  75.120003   51   62   58          102.0
# 268498  484439.34375  676334.0625  73.470001  114  120   94          102.0
# 268499  484439.40625  676334.1875  72.309998  108  115   89          102.0
# 268500  484439.50000  676334.3125  70.440002  108  117   90          102.0
# 268501  484439.81250  676334.1875  72.230003  115  122   96          102.0
# 268502  484440.15625  676334.2500  72.320000  119  124  101          102.0
# 268503  484440.31250  676334.4375  69.510002  112  120   98          102.0
# 268504  484440.68750  676334.4375  70.150002  109  117   97          102.0
# 268505  484440.90625  676334.2500  72.839996  118  123  105          102.0
# 268506  484441.06250  676334.4375  70.470001  111  120  102          102.0
# 268507  484441.09375  676334.5000  69.510002  110  120  103          102.0
# 268508  484441.25000  676334.7500  66.809998   89  100   85          102.0
# 268509  484441.40625  676334.4375  70.790001  106  115   98          102.0
# 268510  484441.56250  676334.1250  75.400002  123  126  112          102.0
# 268511  484441.90625  676334.1250  75.660004  113  117  103          102.0
# 268512  484442.28125  676334.1250  75.910004  110  113  102          102.0
# 268513  484442.75000  676334.2500  74.500000   68   76   66          102.0
# 268514  484443.25000  676334.5000  72.290001   56   67   59          102.0
# 268515  484444.59375  676334.3125  75.610001   69   76   69          102.0
# 268516  484448.00000  676334.3750  73.629997   67   77   69          102.0
# 268517  484448.53125  676334.5625  71.680000   63   73   65          102.0
# 268518  484449.46875  676334.3750  74.669998   86   95   90          102.0
# 268519  484450.18750  676334.4375  75.110001   61   70   66          102.0
# 268520  484450.62500  676334.4375  75.000000   50   61   57          102.0
# 268521  484439.34375  676333.8750  70.589996  113  118   93          102.0
# 268522  484439.50000  676334.1250  67.519997  114  122   96          102.0
#
#         ScanAngleRank  ScanDirectionFlag  NumberOfReturns  ReturnNumber  \
# 0                25.0                1.0              1.0           1.0
# 1                25.0                1.0              1.0           1.0
# 2                25.0                1.0              1.0           1.0
# 3                25.0                1.0              1.0           1.0
# 4                25.0                1.0              1.0           1.0
# 5                25.0                1.0              1.0           1.0
# 6                25.0                1.0              1.0           1.0
# 7                25.0                1.0              1.0           1.0
# 8                25.0                1.0              1.0           1.0
# 9                25.0                1.0              1.0           1.0
# 10               25.0                1.0              1.0           1.0
# 11               25.0                1.0              1.0           1.0
# 12               25.0                1.0              1.0           1.0
# 13               25.0                1.0              1.0           1.0
# 14               25.0                1.0              1.0           1.0
# 15               25.0                1.0              1.0           1.0
# 16               25.0                1.0              1.0           1.0
# 17               25.0                1.0              1.0           1.0
# 18               25.0                1.0              1.0           1.0
# 19               25.0                1.0              1.0           1.0
# 20               25.0                1.0              1.0           1.0
# 21               25.0                1.0              1.0           1.0
# 22               25.0                1.0              1.0           1.0
# 23               25.0                1.0              1.0           1.0
# 24               25.0                1.0              1.0           1.0
# 25               25.0                1.0              1.0           1.0
# 26               25.0                1.0              1.0           1.0
# 27               25.0                1.0              1.0           1.0
# 28               25.0                1.0              1.0           1.0
# 29               25.0                1.0              1.0           1.0
# ...               ...                ...              ...           ...
# 268493            4.0                1.0              2.0           1.0
# 268494            4.0                1.0              2.0           1.0
# 268495            4.0                1.0              2.0           1.0
# 268496            4.0                1.0              2.0           1.0
# 268497            4.0                1.0              2.0           1.0
# 268498            3.0                1.0              3.0           1.0
# 268499            3.0                1.0              3.0           2.0
# 268500            3.0                1.0              3.0           3.0
# 268501            3.0                1.0              2.0           1.0
# 268502            3.0                1.0              3.0           1.0
# 268503            3.0                1.0              3.0           2.0
# 268504            3.0                1.0              2.0           1.0
# 268505            3.0                1.0              5.0           1.0
# 268506            3.0                1.0              5.0           2.0
# 268507            3.0                1.0              5.0           3.0
# 268508            3.0                1.0              5.0           4.0
# 268509            3.0                1.0              2.0           1.0
# 268510            3.0                1.0              2.0           1.0
# 268511            3.0                1.0              2.0           1.0
# 268512            3.0                1.0              2.0           1.0
# 268513            3.0                1.0              2.0           1.0
# 268514            3.0                1.0              2.0           1.0
# 268515            4.0                1.0              2.0           1.0
# 268516            4.0                1.0              2.0           1.0
# 268517            4.0                1.0              2.0           1.0
# 268518            4.0                1.0              2.0           1.0
# 268519            4.0                1.0              2.0           1.0
# 268520            4.0                1.0              2.0           1.0
# 268521            3.0                1.0              3.0           1.0
# 268522            3.0                1.0              3.0           2.0
#
#         Intensity
# 0            64.0
# 1            60.0
# 2            62.0
# 3            64.0
# 4            70.0
# 5            63.0
# 6            63.0
# 7            57.0
# 8            54.0
# 9            58.0
# 10           61.0
# 11           64.0
# 12           65.0
# 13           63.0
# 14           53.0
# 15           55.0
# 16           56.0
# 17           63.0
# 18           57.0
# 19           63.0
# 20           59.0
# 21           56.0
# 22           61.0
# 23           60.0
# 24           62.0
# 25           60.0
# 26           60.0
# 27           65.0
# 28           59.0
# 29           59.0
# ...           ...
# 268493       13.0
# 268494       16.0
# 268495       17.0
# 268496       18.0
# 268497       20.0
# 268498       12.0
# 268499       20.0
# 268500       26.0
# 268501       19.0
# 268502       26.0
# 268503       14.0
# 268504       15.0
# 268505       11.0
# 268506       15.0
# 268507       21.0
# 268508       11.0
# 268509       24.0
# 268510       20.0
# 268511       21.0
# 268512       21.0
# 268513       13.0
# 268514       16.0
# 268515       11.0
# 268516       12.0
# 268517       17.0
# 268518       14.0
# 268519       23.0
# 268520       15.0
# 268521       19.0
# 268522       17.0
#
# [268523 rows x 12 columns]

# %%
test = SelectKBest(score_func=chi2, k=8)  #8 attributes from 12 chosen to potentially delete 4 mentioned above
fit = test.fit(X, y)

# %%
print(fit.scores_)
# Out:
# [1.678e+02 2.203e+00 4.539e+04 1.389e+05 1.236e+05 2.676e+05 1.871e+00
#  3.398e+04 0.000e+00 1.325e+04 5.013e+02 7.182e+05]

# %%
features = fit.transform(X)
print(features[0:6,:]) # summarize selected features
# Out:
# [[ 49.34 124.   124.   112.    25.     1.     1.    64.  ]
#  [ 49.32 124.   125.   115.    25.     1.     1.    60.  ]
#  [ 49.31 123.   124.   113.    25.     1.     1.    62.  ]
#  [ 49.34 122.   122.   112.    25.     1.     1.    64.  ]
#  [ 49.32 122.   122.   112.    25.     1.     1.    70.  ]
#  [ 49.32 125.   125.   115.    25.     1.     1.    63.  ]]
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/sklearn/utils/__init__.py:54: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):

# %% [markdown]
# We can see that __'PointSourceId'__ and __'ScanDirectionFlag'__ had almost null values and __'X'__ and __'Y'__ were also not in top 8  feature selection scores.

# %%
tt_area = tt_area.drop(['PointSourceId', 'ScanDirectionFlag', 'X', 'Y'], axis = 1)

# %% [markdown]
# Next we will analyze __'Classification'__ feature.
#
# Formal LiDAR Data Classification conists of 18 Classification Codes:
#
# __0__ / __1__ - Never classified / Unassigned,
#
# __2__ - Ground,
#
# __3__ / __4__ / __5__ - Low Vegetation / Medium Vegetation / High Vegetation,
#
# __6__ - Building,
#
# __7__ - Noise,
#
# __8__ - Model Key,
#
# __9__ - Water,
#
# __10__ / __11__ - Rail / Road (Surface),
#
# __12__ - Overlap (Reserved),
#
# __13__ / __14__ / __15__ / __16__ - Wire-Guard / Wire-Conductor / Transmission Tower / Wire-Connector
#
# __17__ - Bridge Deck
#
# __18__ - High Noise

# %%
np.unique(tt_area.Classification, return_counts=True) #calculate how many values there are in every Class
# Out:
# (array([ 0.,  2.,  3.,  4.,  5.,  6.,  7., 12.]),
#  array([  9073, 226767,   5630,   2924,  14076,   9859,      3,    191]))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(tt_area.Classification, color = 'skyblue')

plt.title('LiDAR points in each class')

plt.show()

# %% [markdown]
# We can observe that the vast majority of values classify as Ground(2), so we are dealing with a disproportionate ratio of observations in each class, that will obviously lower our measures performance. There are also no 1 and 8+ classes.
#
# ### 1.2 Data sampling
#
# We will use __down-sampling__ for majority class - Ground(2), and __up-sampling__ for other classes, setting the number of samples to match __5000 features__ for all categories.
#
# We will use the scheme of Up-sample Minority Class and Down-sample Majority Class from  https://elitedatascience.com/imbalanced-classes.
#
# First we have to split our data to __train / test__ datasets in order not to interfere with further model accuracy measurement on test data.

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# %%
X = tt_area.iloc[:,0:8]
X.head(5)
# Out:
#            Z    R    G    B  ScanAngleRank  NumberOfReturns  ReturnNumber  \
# 0  49.340000  124  124  112          -25.0              1.0           1.0
# 1  49.320000  124  125  115          -25.0              1.0           1.0
# 2  49.310001  123  124  113          -25.0              1.0           1.0
# 3  49.340000  122  122  112          -25.0              1.0           1.0
# 4  49.320000  122  122  112          -25.0              1.0           1.0
#
#    Intensity
# 0       64.0
# 1       60.0
# 2       62.0
# 3       64.0
# 4       70.0

# %%
y = tt_area.iloc[:,8]
y.head(5)
# Out:
# 0    12.0
# 1    12.0
# 2    12.0
# 3    12.0
# 4    12.0
# Name: Classification, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33)

# %% [markdown]
# Next we concatenate our X_train and y_train data in order to handle our imbalanced classes.

# %%
tt_area_train = pd.concat([X_train, y_train], axis=1, join='inner')
print(tt_area_train.head(5))
# Out:
#                 Z    R    G    B  ScanAngleRank  NumberOfReturns  \
# 208905  55.770000  112  109  102           -3.0              1.0
# 222974  55.880001  107  107  100           -2.0              1.0
# 223236  55.939999  111  107  104           -1.0              1.0
# 35531   52.290001   69   68   66           -9.0              1.0
# 85908   55.480000  184  171  145           -3.0              1.0
#
#         ReturnNumber  Intensity  Classification
# 208905           1.0       57.0             2.0
# 222974           1.0       55.0             2.0
# 223236           1.0       65.0             2.0
# 35531            1.0       98.0             2.0
# 85908            1.0      128.0             2.0

# %%
print(tt_area_train.Classification.value_counts()) # train data imbalanced classes
# Out:
# 2.0     151872
# 5.0       9381
# 6.0       6640
# 0.0       6148
# 3.0       3776
# 4.0       1959
# 12.0       133
# 7.0          1
# Name: Classification, dtype: int64

# %%
random_state = 123
n_samples = 25000

# %%
tt_area_majority_2 = tt_area_train[tt_area_train.Classification==2] # extraction of Ground features

# %%
tt_area_majority_2_upsampled = resample(tt_area_majority_2, 
                                 replace=False,              # sample without replacement
                                 n_samples=n_samples,        # n_samples chosen for down-sampling
                                 random_state=random_state)  # reproducible results

# %%
tt_area_minority_0 = tt_area_train[tt_area_train.Classification==0] # extraction of Never classified features
tt_area_minority_3 = tt_area_train[tt_area_train.Classification==3] # extraction of Low Vegetation features
tt_area_minority_4 = tt_area_train[tt_area_train.Classification==4] # extraction of Medium Vegetation features
tt_area_minority_5 = tt_area_train[tt_area_train.Classification==5] # extraction of High Vegetation features
tt_area_minority_6 = tt_area_train[tt_area_train.Classification==6] # extraction of Building features
tt_area_minority_7 = tt_area_train[tt_area_train.Classification==7] # extraction of Noise features
tt_area_minority_12 = tt_area_train[tt_area_train.Classification==12] # extraction of Overlap (Reserved) features

# %%
tt_area_minority_0_upsampled = resample(tt_area_minority_0, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_3_upsampled = resample(tt_area_minority_3, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_4_upsampled = resample(tt_area_minority_4, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_5_upsampled = resample(tt_area_minority_5, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_6_upsampled = resample(tt_area_minority_6, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_7_upsampled = resample(tt_area_minority_7, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

tt_area_minority_12_upsampled = resample(tt_area_minority_12, 
                                 replace=True,               # sample with replacement
                                 n_samples=n_samples,        # to match majority class
                                 random_state=random_state)  # reproducible results

# %% [markdown]
# Next we join our training sampled data together.

# %%
tt_area_train_sampled = pd.concat([tt_area_minority_0_upsampled, tt_area_majority_2_upsampled, 
                                     tt_area_minority_3_upsampled, tt_area_minority_4_upsampled, 
                                     tt_area_minority_5_upsampled, tt_area_minority_6_upsampled, 
                                     tt_area_minority_7_upsampled, tt_area_minority_12_upsampled ])

# %% [markdown]
# So now the new train dataset has more observations than the original and the ratio of the all classes is now 1:1.

# %%
tt_area_train_sampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 45464 to 12
# Data columns (total 9 columns):
# Z                  200000 non-null float64
# R                  200000 non-null int64
# G                  200000 non-null int64
# B                  200000 non-null int64
# ScanAngleRank      200000 non-null float64
# NumberOfReturns    200000 non-null float64
# ReturnNumber       200000 non-null float64
# Intensity          200000 non-null float64
# Classification     200000 non-null float64
# dtypes: float64(6), int64(3)
# memory usage: 15.3 MB

# %%
tt_area_train_sampled.Classification.value_counts() #we now have 200 000 points in our training dataset
# Out:
# 7.0     25000
# 12.0    25000
# 5.0     25000
# 6.0     25000
# 4.0     25000
# 3.0     25000
# 2.0     25000
# 0.0     25000
# Name: Classification, dtype: int64

# %%
X_train = tt_area_train_sampled.iloc[:, :8]
y_train = tt_area_train_sampled.iloc[:, 8]

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()

# %%
X_train = mm.fit_transform(X_train)
X_test = mm.fit_transform(X_test)

# %% [markdown]
# ### 1.3 XGBoost - default
#
# In next step we will use an advanced implementation of gradient boosting algorithm - __XGBoost__.
#
# First with default settings (we will work only with scaled data from now on).

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from xgboost.sklearn import XGBClassifier
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
y_pred = model_xgb.predict(X_train)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_train, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print(model_xgb)
# Out:
# Accuracy: 83.09%
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_pred = model_xgb.predict(X_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 71.07%

# %% [markdown]
# Over 71% accuracy is not bad, but with 12% accuracy decrease we could already encounter overfitting problem.
#
#
# ### 1.4 XGBoost - tuning
#
#
# Below we will tune XGBoost parameters and see if our accuracy score on train and test data got better.
#
# We will make use of https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/ guide as optimization scheme.
#
# The various steps to be performed are:
#
# 1. Choosing default __learning rate__ and __number of trees__
# 2. Tune __max_depth__ and __min_child_weight__
# 3. Tune __gamma__
# 4. Tune __subsample__ and __colsample_bytree__
# 5. Tuning of __regularization parameters__
# 6. Reducing __learning rate__ and adding __more trees__.
#
# Let us look at a more detailed step by step approach.
#
# First we will set default values for:
# * learning rate - 0.1,
# * number of trees - 100,
#
# which will be changed after remaining parameters optimalization.
#
# Next we will set __GridSearchCV__ with __5 cross-validation__ value and tune __max_depth__ and __min_child_weight__ as they will most likely have the highest impact on model outcome.

# %%
from sklearn.model_selection import GridSearchCV


params = {
    'max_depth':[5,10,20],
    'min_child_weight':[1,3,5]
}

gscv1 = GridSearchCV(estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
                                            colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
                                            missing=None, n_estimators=100, n_jobs=1, nthread=None, 
                                            objective='multi:softprob', random_state=0, reg_alpha=0, reg_lambda=1,
                                            scale_pos_weight=1, seed=None, silent=True, subsample=1),
                                            param_grid = params, cv=5, verbose=100)


gscv1.fit(X_train,y_train)

s = gscv1.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=5, min_child_weight=1 .................................
# [CV] .. max_depth=5, min_child_weight=1, score=0.873400, total= 1.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.4min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=1 .................................
# [CV] .. max_depth=5, min_child_weight=1, score=0.875125, total= 1.3min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.9min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=1 .................................
# [CV] .. max_depth=5, min_child_weight=1, score=0.872900, total= 1.3min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  4.3min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=1 .................................
# [CV] .. max_depth=5, min_child_weight=1, score=0.872900, total= 1.3min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  5.7min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=1 .................................
# [CV] .. max_depth=5, min_child_weight=1, score=0.874325, total= 1.3min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  7.1min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=3 .................................
# [CV] .. max_depth=5, min_child_weight=3, score=0.872875, total= 1.3min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  8.6min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=3 .................................
# [CV] .. max_depth=5, min_child_weight=3, score=0.873025, total= 1.3min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 10.0min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=3 .................................
# [CV] .. max_depth=5, min_child_weight=3, score=0.870375, total= 1.3min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 11.4min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=3 .................................
# [CV] .. max_depth=5, min_child_weight=3, score=0.871100, total= 1.3min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 12.8min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=3 .................................
# [CV] .. max_depth=5, min_child_weight=3, score=0.872100, total= 1.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 14.3min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] .. max_depth=5, min_child_weight=5, score=0.872125, total= 1.3min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 15.7min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] .. max_depth=5, min_child_weight=5, score=0.873100, total= 1.3min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 17.1min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] .. max_depth=5, min_child_weight=5, score=0.870625, total= 1.3min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 18.5min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] .. max_depth=5, min_child_weight=5, score=0.871750, total= 1.3min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 19.9min remaining:    0.0s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] .. max_depth=5, min_child_weight=5, score=0.873375, total= 1.3min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 21.4min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=1 ................................
# [CV] . max_depth=10, min_child_weight=1, score=0.957600, total= 2.2min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 23.8min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=1 ................................
# [CV] . max_depth=10, min_child_weight=1, score=0.954375, total= 2.3min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 26.2min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=1 ................................
# [CV] . max_depth=10, min_child_weight=1, score=0.952425, total= 2.2min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 28.6min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=1 ................................
# [CV] . max_depth=10, min_child_weight=1, score=0.954500, total= 2.3min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 31.1min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=1 ................................
# [CV] . max_depth=10, min_child_weight=1, score=0.953500, total= 2.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 33.5min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=3 ................................
# [CV] . max_depth=10, min_child_weight=3, score=0.954375, total= 2.3min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 35.9min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=3 ................................
# [CV] . max_depth=10, min_child_weight=3, score=0.954125, total= 2.2min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 38.3min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=3 ................................
# [CV] . max_depth=10, min_child_weight=3, score=0.951600, total= 2.2min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 40.7min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=3 ................................
# [CV] . max_depth=10, min_child_weight=3, score=0.949750, total= 2.2min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 43.2min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=3 ................................
# [CV] . max_depth=10, min_child_weight=3, score=0.952475, total= 2.2min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 45.5min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] . max_depth=10, min_child_weight=5, score=0.950075, total= 2.2min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 47.9min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] . max_depth=10, min_child_weight=5, score=0.950775, total= 2.2min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 50.3min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] . max_depth=10, min_child_weight=5, score=0.948200, total= 2.2min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 52.7min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] . max_depth=10, min_child_weight=5, score=0.946125, total= 2.2min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 55.1min remaining:    0.0s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] . max_depth=10, min_child_weight=5, score=0.950125, total= 2.2min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 57.5min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.989350, total= 3.6min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 61.4min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988250, total= 3.7min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 65.3min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988550, total= 3.7min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 69.2min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.987775, total= 3.6min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 73.1min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988450, total= 3.7min
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 77.0min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=3 ................................
# [CV] . max_depth=20, min_child_weight=3, score=0.988375, total= 3.6min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 80.9min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=3 ................................
# [CV] . max_depth=20, min_child_weight=3, score=0.986875, total= 3.5min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 84.7min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=3 ................................
# [CV] . max_depth=20, min_child_weight=3, score=0.987150, total= 3.5min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 88.5min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=3 ................................
# [CV] . max_depth=20, min_child_weight=3, score=0.986425, total= 3.6min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 92.3min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=3 ................................
# [CV] . max_depth=20, min_child_weight=3, score=0.987475, total= 3.5min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 96.1min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=5 ................................
# [CV] . max_depth=20, min_child_weight=5, score=0.986250, total= 3.5min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 99.9min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=5 ................................
# [CV] . max_depth=20, min_child_weight=5, score=0.985125, total= 3.5min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 103.6min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=5 ................................
# [CV] . max_depth=20, min_child_weight=5, score=0.985050, total= 3.5min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 107.4min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=5 ................................
# [CV] . max_depth=20, min_child_weight=5, score=0.984550, total= 3.6min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 111.2min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=5 ................................
# [CV] . max_depth=20, min_child_weight=5, score=0.985275, total= 3.5min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 115.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 115.0min finished
# [mean: 0.98847, std: 0.00051, params: {'max_depth': 20, 'min_child_weight': 1},
#  mean: 0.98726, std: 0.00066, params: {'max_depth': 20, 'min_child_weight': 3},
#  mean: 0.98525, std: 0.00056, params: {'max_depth': 20, 'min_child_weight': 5},
#  mean: 0.95448, std: 0.00173, params: {'max_depth': 10, 'min_child_weight': 1},
#  mean: 0.95247, std: 0.00170, params: {'max_depth': 10, 'min_child_weight': 3},
#  mean: 0.94906, std: 0.00170, params: {'max_depth': 10, 'min_child_weight': 5},
#  mean: 0.87373, std: 0.00087, params: {'max_depth': 5, 'min_child_weight': 1},
#  mean: 0.87220, std: 0.00099, params: {'max_depth': 5, 'min_child_weight': 5},
#  mean: 0.87189, std: 0.00102, params: {'max_depth': 5, 'min_child_weight': 3}]

# %% [markdown]
# We see 20 as the optimal value for __max_depth__ and  for __min_child_weight__ and because these are our extreme values we will search for more precise values.

# %%
xgb = XGBClassifier(**gscv1.best_params_)
params = {'max_depth': [20,30,40,50],
         'min_child_weight': [1,2]}
gscv2 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv2.fit(X_train,y_train)
s = gscv2.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.989350, total= 3.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.9min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988250, total= 3.6min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  7.8min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988550, total= 3.6min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 11.7min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.987775, total= 3.6min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 15.6min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=1 ................................
# [CV] . max_depth=20, min_child_weight=1, score=0.988450, total= 3.6min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 19.5min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=2 ................................
# [CV] . max_depth=20, min_child_weight=2, score=0.989250, total= 3.6min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 23.4min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=2 ................................
# [CV] . max_depth=20, min_child_weight=2, score=0.987900, total= 3.8min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 27.4min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=2 ................................
# [CV] . max_depth=20, min_child_weight=2, score=0.987900, total= 3.6min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 31.3min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=2 ................................
# [CV] . max_depth=20, min_child_weight=2, score=0.986800, total= 3.6min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 35.2min remaining:    0.0s
# [CV] max_depth=20, min_child_weight=2 ................................
# [CV] . max_depth=20, min_child_weight=2, score=0.988050, total= 3.6min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 39.0min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=1 ................................
# [CV] . max_depth=30, min_child_weight=1, score=0.989900, total= 4.4min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 43.8min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=1 ................................
# [CV] . max_depth=30, min_child_weight=1, score=0.989050, total= 4.4min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 48.5min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=1 ................................
# [CV] . max_depth=30, min_child_weight=1, score=0.989175, total= 4.4min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 53.2min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=1 ................................
# [CV] . max_depth=30, min_child_weight=1, score=0.988425, total= 4.4min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 58.0min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=1 ................................
# [CV] . max_depth=30, min_child_weight=1, score=0.989375, total= 4.4min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 62.7min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=2 ................................
# [CV] . max_depth=30, min_child_weight=2, score=0.989575, total= 4.4min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 67.4min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=2 ................................
# [CV] . max_depth=30, min_child_weight=2, score=0.988925, total= 4.3min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 72.1min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=2 ................................
# [CV] . max_depth=30, min_child_weight=2, score=0.988875, total= 4.4min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 76.7min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=2 ................................
# [CV] . max_depth=30, min_child_weight=2, score=0.988000, total= 4.4min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 81.4min remaining:    0.0s
# [CV] max_depth=30, min_child_weight=2 ................................
# [CV] . max_depth=30, min_child_weight=2, score=0.988775, total= 4.4min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 86.1min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=1 ................................
# [CV] . max_depth=40, min_child_weight=1, score=0.989900, total= 4.8min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 91.2min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=1 ................................
# [CV] . max_depth=40, min_child_weight=1, score=0.989275, total= 4.7min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 96.2min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=1 ................................
# [CV] . max_depth=40, min_child_weight=1, score=0.989200, total= 4.8min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 101.3min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=1 ................................
# [CV] . max_depth=40, min_child_weight=1, score=0.988475, total= 4.7min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 106.4min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=1 ................................
# [CV] . max_depth=40, min_child_weight=1, score=0.989075, total= 4.8min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 111.5min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=2 ................................
# [CV] . max_depth=40, min_child_weight=2, score=0.989500, total= 4.7min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 116.5min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=2 ................................
# [CV] . max_depth=40, min_child_weight=2, score=0.988625, total= 4.7min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 121.6min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=2 ................................
# [CV] . max_depth=40, min_child_weight=2, score=0.988950, total= 4.7min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 126.6min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=2 ................................
# [CV] . max_depth=40, min_child_weight=2, score=0.987925, total= 4.7min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 131.7min remaining:    0.0s
# [CV] max_depth=40, min_child_weight=2 ................................
# [CV] . max_depth=40, min_child_weight=2, score=0.989250, total= 4.7min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 136.7min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=1 ................................
# [CV] . max_depth=50, min_child_weight=1, score=0.990250, total= 4.9min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 141.9min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=1 ................................
# [CV] . max_depth=50, min_child_weight=1, score=0.989325, total= 4.8min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 147.1min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=1 ................................
# [CV] . max_depth=50, min_child_weight=1, score=0.989400, total= 4.8min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 152.2min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=1 ................................
# [CV] . max_depth=50, min_child_weight=1, score=0.988575, total= 4.9min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 157.4min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=1 ................................
# [CV] . max_depth=50, min_child_weight=1, score=0.989375, total= 4.9min
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 162.6min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=2 ................................
# [CV] . max_depth=50, min_child_weight=2, score=0.989775, total= 4.9min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 167.8min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=2 ................................
# [CV] . max_depth=50, min_child_weight=2, score=0.988950, total= 4.9min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 173.0min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=2 ................................
# [CV] . max_depth=50, min_child_weight=2, score=0.988850, total= 4.9min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 178.2min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=2 ................................
# [CV] . max_depth=50, min_child_weight=2, score=0.988325, total= 4.9min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 183.4min remaining:    0.0s
# [CV] max_depth=50, min_child_weight=2 ................................
# [CV] . max_depth=50, min_child_weight=2, score=0.989150, total= 4.9min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 188.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 188.6min finished
# [mean: 0.98938, std: 0.00053, params: {'max_depth': 50, 'min_child_weight': 1},
#  mean: 0.98918, std: 0.00048, params: {'max_depth': 30, 'min_child_weight': 1},
#  mean: 0.98918, std: 0.00046, params: {'max_depth': 40, 'min_child_weight': 1},
#  mean: 0.98901, std: 0.00047, params: {'max_depth': 50, 'min_child_weight': 2},
#  mean: 0.98885, std: 0.00055, params: {'max_depth': 40, 'min_child_weight': 2},
#  mean: 0.98883, std: 0.00050, params: {'max_depth': 30, 'min_child_weight': 2},
#  mean: 0.98847, std: 0.00051, params: {'max_depth': 20, 'min_child_weight': 1},
#  mean: 0.98798, std: 0.00078, params: {'max_depth': 20, 'min_child_weight': 2}]

# %% [markdown]
# We will go one step deeper once more and look for optimum values for max_depth.

# %%
xgb = XGBClassifier(**gscv2.best_estimator_.get_params())
params = {'max_depth': [50,60,70,80]
         }
gscv3 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv3.fit(X_train,y_train)
s = gscv3.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] max_depth=50 ....................................................
# [CV] ..................... max_depth=50, score=0.990250, total= 5.0min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.3min remaining:    0.0s
# [CV] max_depth=50 ....................................................
# [CV] ..................... max_depth=50, score=0.989325, total= 4.9min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.5min remaining:    0.0s
# [CV] max_depth=50 ....................................................
# [CV] ..................... max_depth=50, score=0.989400, total= 4.8min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 15.7min remaining:    0.0s
# [CV] max_depth=50 ....................................................
# [CV] ..................... max_depth=50, score=0.988575, total= 4.9min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 20.9min remaining:    0.0s
# [CV] max_depth=50 ....................................................
# [CV] ..................... max_depth=50, score=0.989375, total= 4.9min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 26.1min remaining:    0.0s
# [CV] max_depth=60 ....................................................
# [CV] ..................... max_depth=60, score=0.989875, total= 5.0min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 31.4min remaining:    0.0s
# [CV] max_depth=60 ....................................................
# [CV] ..................... max_depth=60, score=0.989300, total= 5.0min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 36.7min remaining:    0.0s
# [CV] max_depth=60 ....................................................
# [CV] ..................... max_depth=60, score=0.989425, total= 5.0min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 42.0min remaining:    0.0s
# [CV] max_depth=60 ....................................................
# [CV] ..................... max_depth=60, score=0.988700, total= 5.0min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 47.3min remaining:    0.0s
# [CV] max_depth=60 ....................................................
# [CV] ..................... max_depth=60, score=0.989500, total= 5.0min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 52.6min remaining:    0.0s
# [CV] max_depth=70 ....................................................
# [CV] ..................... max_depth=70, score=0.990025, total= 5.0min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 57.9min remaining:    0.0s
# [CV] max_depth=70 ....................................................
# [CV] ..................... max_depth=70, score=0.989400, total= 5.0min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 63.2min remaining:    0.0s
# [CV] max_depth=70 ....................................................
# [CV] ..................... max_depth=70, score=0.989350, total= 4.9min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 68.5min remaining:    0.0s
# [CV] max_depth=70 ....................................................
# [CV] ..................... max_depth=70, score=0.988750, total= 5.0min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 73.8min remaining:    0.0s
# [CV] max_depth=70 ....................................................
# [CV] ..................... max_depth=70, score=0.989275, total= 4.9min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 79.0min remaining:    0.0s
# [CV] max_depth=80 ....................................................
# [CV] ..................... max_depth=80, score=0.990025, total= 5.0min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 84.3min remaining:    0.0s
# [CV] max_depth=80 ....................................................
# [CV] ..................... max_depth=80, score=0.989275, total= 5.0min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 89.6min remaining:    0.0s
# [CV] max_depth=80 ....................................................
# [CV] ..................... max_depth=80, score=0.989400, total= 4.9min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 94.9min remaining:    0.0s
# [CV] max_depth=80 ....................................................
# [CV] ..................... max_depth=80, score=0.988725, total= 5.0min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 100.2min remaining:    0.0s
# [CV] max_depth=80 ....................................................
# [CV] ..................... max_depth=80, score=0.989125, total= 5.0min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 105.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 105.5min finished
# [mean: 0.98938, std: 0.00053, params: {'max_depth': 50},
#  mean: 0.98936, std: 0.00038, params: {'max_depth': 60},
#  mean: 0.98936, std: 0.00041, params: {'max_depth': 70},
#  mean: 0.98931, std: 0.00042, params: {'max_depth': 80}]

# %% [markdown]
# We see that picking __50 max_depth__ value was the right way to go. So now we've got the optimum values of __50__ for __max_depth__ and __1__ for __min_child_weight__.
#
# Subsequently we will tune __gamma value__ using the parameters already tuned above.

# %%
xgb = XGBClassifier(**gscv3.best_estimator_.get_params())
params = {'gamma':[0.0,0.1,0.2,0.3,0.4]
          
         }
gscv4 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv4.fit(X_train,y_train)
s = gscv4.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] gamma=0.0 .......................................................
# [CV] ........................ gamma=0.0, score=0.990250, total= 4.9min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.2min remaining:    0.0s
# [CV] gamma=0.0 .......................................................
# [CV] ........................ gamma=0.0, score=0.989325, total= 4.9min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.5min remaining:    0.0s
# [CV] gamma=0.0 .......................................................
# [CV] ........................ gamma=0.0, score=0.989400, total= 4.9min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 15.7min remaining:    0.0s
# [CV] gamma=0.0 .......................................................
# [CV] ........................ gamma=0.0, score=0.988575, total= 5.3min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 21.3min remaining:    0.0s
# [CV] gamma=0.0 .......................................................
# [CV] ........................ gamma=0.0, score=0.989375, total= 4.9min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 26.5min remaining:    0.0s
# [CV] gamma=0.1 .......................................................
# [CV] ........................ gamma=0.1, score=0.989825, total= 5.0min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 31.9min remaining:    0.0s
# [CV] gamma=0.1 .......................................................
# [CV] ........................ gamma=0.1, score=0.988950, total= 4.9min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 37.1min remaining:    0.0s
# [CV] gamma=0.1 .......................................................
# [CV] ........................ gamma=0.1, score=0.989050, total= 5.0min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 42.4min remaining:    0.0s
# [CV] gamma=0.1 .......................................................
# [CV] ........................ gamma=0.1, score=0.988475, total= 4.9min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 47.6min remaining:    0.0s
# [CV] gamma=0.1 .......................................................
# [CV] ........................ gamma=0.1, score=0.989025, total= 4.9min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 52.9min remaining:    0.0s
# [CV] gamma=0.2 .......................................................
# [CV] ........................ gamma=0.2, score=0.989800, total= 5.0min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 58.2min remaining:    0.0s
# [CV] gamma=0.2 .......................................................
# [CV] ........................ gamma=0.2, score=0.988900, total= 5.0min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 63.5min remaining:    0.0s
# [CV] gamma=0.2 .......................................................
# [CV] ........................ gamma=0.2, score=0.988875, total= 5.1min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 68.9min remaining:    0.0s
# [CV] gamma=0.2 .......................................................
# [CV] ........................ gamma=0.2, score=0.988250, total= 5.0min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 74.2min remaining:    0.0s
# [CV] gamma=0.2 .......................................................
# [CV] ........................ gamma=0.2, score=0.988925, total= 5.0min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 79.6min remaining:    0.0s
# [CV] gamma=0.3 .......................................................
# [CV] ........................ gamma=0.3, score=0.989650, total= 5.2min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 85.1min remaining:    0.0s
# [CV] gamma=0.3 .......................................................
# [CV] ........................ gamma=0.3, score=0.988500, total= 5.1min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 90.6min remaining:    0.0s
# [CV] gamma=0.3 .......................................................
# [CV] ........................ gamma=0.3, score=0.989000, total= 5.1min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 96.0min remaining:    0.0s
# [CV] gamma=0.3 .......................................................
# [CV] ........................ gamma=0.3, score=0.988150, total= 5.1min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 101.5min remaining:    0.0s
# [CV] gamma=0.3 .......................................................
# [CV] ........................ gamma=0.3, score=0.989100, total= 5.1min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 107.0min remaining:    0.0s
# [CV] gamma=0.4 .......................................................
# [CV] ........................ gamma=0.4, score=0.989575, total= 5.3min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 112.6min remaining:    0.0s
# [CV] gamma=0.4 .......................................................
# [CV] ........................ gamma=0.4, score=0.988625, total= 5.3min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 118.2min remaining:    0.0s
# [CV] gamma=0.4 .......................................................
# [CV] ........................ gamma=0.4, score=0.988325, total= 5.3min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 123.8min remaining:    0.0s
# [CV] gamma=0.4 .......................................................
# [CV] ........................ gamma=0.4, score=0.987950, total= 5.3min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 129.4min remaining:    0.0s
# [CV] gamma=0.4 .......................................................
# [CV] ........................ gamma=0.4, score=0.988850, total= 5.3min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 134.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 134.9min finished
# [mean: 0.98938, std: 0.00053, params: {'gamma': 0.0},
#  mean: 0.98906, std: 0.00043, params: {'gamma': 0.1},
#  mean: 0.98895, std: 0.00049, params: {'gamma': 0.2},
#  mean: 0.98888, std: 0.00052, params: {'gamma': 0.3},
#  mean: 0.98867, std: 0.00055, params: {'gamma': 0.4}]

# %% [markdown]
# We've got the optimum value of __0.0__ for __gamma__ parameter.
#
# Next we will tune __subsample__ and __colsample_bytree__ with values 0.6, 0.7, 0.8, 0.9 for both.

# %%
xgb = XGBClassifier(**gscv4.best_estimator_.get_params())
params = {'subsample':[0.6,0.7,0.8,0.9],
         'colsample_bytree':[0.6,0.7,0.8,0.9]

         }
gscv5 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv5.fit(X_train,y_train)
s = gscv5.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV]  colsample_bytree=0.6, subsample=0.6, score=0.990475, total= 3.2min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.7min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV]  colsample_bytree=0.6, subsample=0.6, score=0.989675, total= 3.5min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  7.8min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV]  colsample_bytree=0.6, subsample=0.6, score=0.989800, total= 3.2min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 11.5min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV]  colsample_bytree=0.6, subsample=0.6, score=0.989275, total= 3.2min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 15.2min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV]  colsample_bytree=0.6, subsample=0.6, score=0.990200, total= 3.2min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 18.9min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV]  colsample_bytree=0.6, subsample=0.7, score=0.991350, total= 3.1min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 22.5min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV]  colsample_bytree=0.6, subsample=0.7, score=0.989850, total= 3.2min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 26.2min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV]  colsample_bytree=0.6, subsample=0.7, score=0.990350, total= 3.2min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 29.9min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV]  colsample_bytree=0.6, subsample=0.7, score=0.990125, total= 3.1min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 33.6min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV]  colsample_bytree=0.6, subsample=0.7, score=0.990450, total= 3.2min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 37.3min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV]  colsample_bytree=0.6, subsample=0.8, score=0.991325, total= 3.1min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 40.9min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV]  colsample_bytree=0.6, subsample=0.8, score=0.990300, total= 3.2min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 44.6min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV]  colsample_bytree=0.6, subsample=0.8, score=0.990775, total= 3.1min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 48.2min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV]  colsample_bytree=0.6, subsample=0.8, score=0.990350, total= 3.2min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 52.0min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV]  colsample_bytree=0.6, subsample=0.8, score=0.990675, total= 3.2min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 55.6min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV]  colsample_bytree=0.6, subsample=0.9, score=0.991525, total= 3.2min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 59.4min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV]  colsample_bytree=0.6, subsample=0.9, score=0.990150, total= 3.2min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 63.1min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV]  colsample_bytree=0.6, subsample=0.9, score=0.990750, total= 3.2min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 66.7min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV]  colsample_bytree=0.6, subsample=0.9, score=0.990350, total= 3.1min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 70.4min remaining:    0.0s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV]  colsample_bytree=0.6, subsample=0.9, score=0.990900, total= 3.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 74.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV]  colsample_bytree=0.7, subsample=0.6, score=0.990450, total= 3.6min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 78.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV]  colsample_bytree=0.7, subsample=0.6, score=0.989400, total= 3.6min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 82.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV]  colsample_bytree=0.7, subsample=0.6, score=0.989825, total= 3.5min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 86.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV]  colsample_bytree=0.7, subsample=0.6, score=0.989225, total= 3.5min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 90.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV]  colsample_bytree=0.7, subsample=0.6, score=0.989750, total= 3.5min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 94.0min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV]  colsample_bytree=0.7, subsample=0.7, score=0.990525, total= 3.5min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 98.0min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV]  colsample_bytree=0.7, subsample=0.7, score=0.990300, total= 3.6min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 102.0min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV]  colsample_bytree=0.7, subsample=0.7, score=0.989675, total= 3.6min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 106.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV]  colsample_bytree=0.7, subsample=0.7, score=0.989625, total= 3.8min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 110.3min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV]  colsample_bytree=0.7, subsample=0.7, score=0.990275, total= 3.5min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 114.2min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV]  colsample_bytree=0.7, subsample=0.8, score=0.991050, total= 3.5min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 118.2min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV]  colsample_bytree=0.7, subsample=0.8, score=0.990025, total= 3.5min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 122.2min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV]  colsample_bytree=0.7, subsample=0.8, score=0.990275, total= 3.7min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 126.3min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV]  colsample_bytree=0.7, subsample=0.8, score=0.989550, total= 3.5min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 130.2min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV]  colsample_bytree=0.7, subsample=0.8, score=0.990375, total= 3.6min
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 134.2min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV]  colsample_bytree=0.7, subsample=0.9, score=0.991000, total= 3.5min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 138.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV]  colsample_bytree=0.7, subsample=0.9, score=0.990350, total= 3.5min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 142.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV]  colsample_bytree=0.7, subsample=0.9, score=0.990350, total= 3.5min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 146.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV]  colsample_bytree=0.7, subsample=0.9, score=0.990000, total= 3.5min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 150.1min remaining:    0.0s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV]  colsample_bytree=0.7, subsample=0.9, score=0.990600, total= 3.5min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 154.1min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV]  colsample_bytree=0.8, subsample=0.6, score=0.990425, total= 4.0min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 158.4min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV]  colsample_bytree=0.8, subsample=0.6, score=0.989675, total= 4.0min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 162.9min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV]  colsample_bytree=0.8, subsample=0.6, score=0.989725, total= 4.0min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 167.2min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV]  colsample_bytree=0.8, subsample=0.6, score=0.988750, total= 3.9min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 171.6min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV]  colsample_bytree=0.8, subsample=0.6, score=0.989950, total= 3.9min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 175.8min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV]  colsample_bytree=0.8, subsample=0.7, score=0.991075, total= 4.0min
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 180.2min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV]  colsample_bytree=0.8, subsample=0.7, score=0.989450, total= 5.5min
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 186.1min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV]  colsample_bytree=0.8, subsample=0.7, score=0.989750, total= 4.0min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 190.5min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV]  colsample_bytree=0.8, subsample=0.7, score=0.989350, total= 3.9min
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 194.8min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV]  colsample_bytree=0.8, subsample=0.7, score=0.989950, total= 3.9min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 199.2min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV]  colsample_bytree=0.8, subsample=0.8, score=0.991125, total= 3.9min
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 203.5min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV]  colsample_bytree=0.8, subsample=0.8, score=0.989875, total= 3.9min
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 207.8min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV]  colsample_bytree=0.8, subsample=0.8, score=0.990100, total= 3.9min
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 212.2min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV]  colsample_bytree=0.8, subsample=0.8, score=0.989275, total= 3.9min
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 216.5min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV]  colsample_bytree=0.8, subsample=0.8, score=0.990100, total= 3.9min
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 220.8min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV]  colsample_bytree=0.8, subsample=0.9, score=0.990800, total= 3.9min
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 225.1min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV]  colsample_bytree=0.8, subsample=0.9, score=0.990250, total= 3.9min
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 229.4min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV]  colsample_bytree=0.8, subsample=0.9, score=0.990675, total= 3.9min
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 233.8min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV]  colsample_bytree=0.8, subsample=0.9, score=0.989425, total= 3.9min
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 238.1min remaining:    0.0s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV]  colsample_bytree=0.8, subsample=0.9, score=0.990425, total= 3.9min
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 242.5min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV]  colsample_bytree=0.9, subsample=0.6, score=0.990275, total= 4.4min
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 247.2min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV]  colsample_bytree=0.9, subsample=0.6, score=0.989350, total= 4.4min
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 252.0min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV]  colsample_bytree=0.9, subsample=0.6, score=0.989225, total= 4.4min
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 256.7min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV]  colsample_bytree=0.9, subsample=0.6, score=0.988925, total= 4.4min
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed: 261.5min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV]  colsample_bytree=0.9, subsample=0.6, score=0.989725, total= 4.3min
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed: 266.2min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV]  colsample_bytree=0.9, subsample=0.7, score=0.990525, total= 4.4min
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed: 271.0min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV]  colsample_bytree=0.9, subsample=0.7, score=0.989575, total= 4.4min
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed: 275.8min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV]  colsample_bytree=0.9, subsample=0.7, score=0.989875, total= 4.4min
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed: 280.5min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV]  colsample_bytree=0.9, subsample=0.7, score=0.988950, total= 4.4min
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed: 285.3min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV]  colsample_bytree=0.9, subsample=0.7, score=0.989750, total= 4.4min
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 290.1min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV]  colsample_bytree=0.9, subsample=0.8, score=0.990550, total= 4.5min
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed: 294.9min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV]  colsample_bytree=0.9, subsample=0.8, score=0.989625, total= 4.4min
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed: 299.8min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV]  colsample_bytree=0.9, subsample=0.8, score=0.989775, total= 4.4min
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed: 304.5min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV]  colsample_bytree=0.9, subsample=0.8, score=0.989100, total= 4.5min
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed: 309.4min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV]  colsample_bytree=0.9, subsample=0.8, score=0.989550, total= 4.4min
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 314.2min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV]  colsample_bytree=0.9, subsample=0.9, score=0.990625, total= 4.4min
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed: 319.0min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV]  colsample_bytree=0.9, subsample=0.9, score=0.989700, total= 4.5min
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed: 323.8min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV]  colsample_bytree=0.9, subsample=0.9, score=0.990175, total= 4.4min
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed: 328.6min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV]  colsample_bytree=0.9, subsample=0.9, score=0.989125, total= 4.4min
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed: 333.5min remaining:    0.0s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV]  colsample_bytree=0.9, subsample=0.9, score=0.989750, total= 4.4min
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed: 338.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed: 338.3min finished
# [mean: 0.99074, std: 0.00048, params: {'colsample_bytree': 0.6, 'subsample': 0.9},
#  mean: 0.99069, std: 0.00037, params: {'colsample_bytree': 0.6, 'subsample': 0.8},
#  mean: 0.99046, std: 0.00033, params: {'colsample_bytree': 0.7, 'subsample': 0.9},
#  mean: 0.99042, std: 0.00051, params: {'colsample_bytree': 0.6, 'subsample': 0.7},
#  mean: 0.99031, std: 0.00048, params: {'colsample_bytree': 0.8, 'subsample': 0.9},
#  mean: 0.99025, std: 0.00049, params: {'colsample_bytree': 0.7, 'subsample': 0.8},
#  mean: 0.99009, std: 0.00060, params: {'colsample_bytree': 0.8, 'subsample': 0.8},
#  mean: 0.99008, std: 0.00036, params: {'colsample_bytree': 0.7, 'subsample': 0.7},
#  mean: 0.98991, std: 0.00062, params: {'colsample_bytree': 0.8, 'subsample': 0.7},
#  mean: 0.98989, std: 0.00042, params: {'colsample_bytree': 0.6, 'subsample': 0.6},
#  mean: 0.98987, std: 0.00050, params: {'colsample_bytree': 0.9, 'subsample': 0.9},
#  mean: 0.98974, std: 0.00051, params: {'colsample_bytree': 0.9, 'subsample': 0.7},
#  mean: 0.98973, std: 0.00042, params: {'colsample_bytree': 0.7, 'subsample': 0.6},
#  mean: 0.98972, std: 0.00047, params: {'colsample_bytree': 0.9, 'subsample': 0.8},
#  mean: 0.98970, std: 0.00055, params: {'colsample_bytree': 0.8, 'subsample': 0.6},
#  mean: 0.98950, std: 0.00046, params: {'colsample_bytree': 0.9, 'subsample': 0.6}]

# %% [markdown]
# We see that __colsample_bytree__: 0.6 and __subsample__: 0.9 were the most optimum values.
#
# Now we will apply regularization (__reg_alpha, reg_lambda__) to reduce overfitting.

# %%
xgb = XGBClassifier(**gscv5.best_estimator_.get_params())
params = {'reg_alpha':[1e-5, 1e-2, 0, 0.1, 1, 100],
          
        }

gscv6 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv6.fit(X_train,y_train)
s = gscv6.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.991550, total= 6.1min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.1min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990550, total= 6.1min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 14.2min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990575, total= 6.2min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 21.3min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990375, total= 6.0min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 28.3min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990750, total= 6.0min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 35.2min remaining:    0.0s
# [CV] reg_alpha=0.01 ..................................................
# [CV] ................... reg_alpha=0.01, score=0.991200, total= 6.1min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 42.2min remaining:    0.0s
# [CV] reg_alpha=0.01 ..................................................
# [CV] ................... reg_alpha=0.01, score=0.990250, total= 6.1min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 49.2min remaining:    0.0s
# [CV] reg_alpha=0.01 ..................................................
# [CV] ................... reg_alpha=0.01, score=0.990525, total= 6.0min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 56.1min remaining:    0.0s
# [CV] reg_alpha=0.01 ..................................................
# [CV] ................... reg_alpha=0.01, score=0.990400, total= 6.2min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 63.2min remaining:    0.0s
# [CV] reg_alpha=0.01 ..................................................
# [CV] ................... reg_alpha=0.01, score=0.990850, total= 6.1min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 70.3min remaining:    0.0s
# [CV] reg_alpha=0 .....................................................
# [CV] ...................... reg_alpha=0, score=0.991525, total= 6.1min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 77.4min remaining:    0.0s
# [CV] reg_alpha=0 .....................................................
# [CV] ...................... reg_alpha=0, score=0.990150, total= 6.1min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 84.4min remaining:    0.0s
# [CV] reg_alpha=0 .....................................................
# [CV] ...................... reg_alpha=0, score=0.990750, total= 6.1min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 91.5min remaining:    0.0s
# [CV] reg_alpha=0 .....................................................
# [CV] ...................... reg_alpha=0, score=0.990350, total= 6.0min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 98.5min remaining:    0.0s
# [CV] reg_alpha=0 .....................................................
# [CV] ...................... reg_alpha=0, score=0.990900, total= 6.1min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 105.5min remaining:    0.0s
# [CV] reg_alpha=0.1 ...................................................
# [CV] .................... reg_alpha=0.1, score=0.991150, total= 6.1min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 112.4min remaining:    0.0s
# [CV] reg_alpha=0.1 ...................................................
# [CV] .................... reg_alpha=0.1, score=0.990300, total= 6.1min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 119.4min remaining:    0.0s
# [CV] reg_alpha=0.1 ...................................................
# [CV] .................... reg_alpha=0.1, score=0.990350, total= 6.0min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 126.4min remaining:    0.0s
# [CV] reg_alpha=0.1 ...................................................
# [CV] .................... reg_alpha=0.1, score=0.990200, total= 5.9min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 133.2min remaining:    0.0s
# [CV] reg_alpha=0.1 ...................................................
# [CV] .................... reg_alpha=0.1, score=0.990700, total= 6.1min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 140.2min remaining:    0.0s
# [CV] reg_alpha=1 .....................................................
# [CV] ...................... reg_alpha=1, score=0.988450, total= 5.7min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 146.7min remaining:    0.0s
# [CV] reg_alpha=1 .....................................................
# [CV] ...................... reg_alpha=1, score=0.987950, total= 5.7min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 153.1min remaining:    0.0s
# [CV] reg_alpha=1 .....................................................
# [CV] ...................... reg_alpha=1, score=0.988250, total= 5.7min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 159.6min remaining:    0.0s
# [CV] reg_alpha=1 .....................................................
# [CV] ...................... reg_alpha=1, score=0.987625, total= 5.6min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 166.1min remaining:    0.0s
# [CV] reg_alpha=1 .....................................................
# [CV] ...................... reg_alpha=1, score=0.988625, total= 5.7min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 172.5min remaining:    0.0s
# [CV] reg_alpha=100 ...................................................
# [CV] .................... reg_alpha=100, score=0.863625, total= 3.1min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 176.0min remaining:    0.0s
# [CV] reg_alpha=100 ...................................................
# [CV] .................... reg_alpha=100, score=0.864550, total= 3.1min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 179.6min remaining:    0.0s
# [CV] reg_alpha=100 ...................................................
# [CV] .................... reg_alpha=100, score=0.864000, total= 3.1min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 183.1min remaining:    0.0s
# [CV] reg_alpha=100 ...................................................
# [CV] .................... reg_alpha=100, score=0.862775, total= 3.1min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 186.7min remaining:    0.0s
# [CV] reg_alpha=100 ...................................................
# [CV] .................... reg_alpha=100, score=0.864675, total= 3.1min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 190.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 190.2min finished
# [mean: 0.99076, std: 0.00041, params: {'reg_alpha': 1e-05},
#  mean: 0.99074, std: 0.00048, params: {'reg_alpha': 0},
#  mean: 0.99064, std: 0.00034, params: {'reg_alpha': 0.01},
#  mean: 0.99054, std: 0.00035, params: {'reg_alpha': 0.1},
#  mean: 0.98818, std: 0.00036, params: {'reg_alpha': 1},
#  mean: 0.86393, std: 0.00069, params: {'reg_alpha': 100}]

# %% [markdown]
# We've got an extreme value of 1e-05 so we will do more investigation.

# %%
xgb = XGBClassifier(**gscv6.best_estimator_.get_params())
params = {'reg_alpha':[1e-9, 1e-7, 1e-5, 1e-3]
          
        }

gscv7 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv7.fit(X_train,y_train)
s = gscv7.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] reg_alpha=1e-09 .................................................
# [CV] .................. reg_alpha=1e-09, score=0.991525, total= 3.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.8min remaining:    0.0s
# [CV] reg_alpha=1e-09 .................................................
# [CV] .................. reg_alpha=1e-09, score=0.990150, total= 3.3min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  7.7min remaining:    0.0s
# [CV] reg_alpha=1e-09 .................................................
# [CV] .................. reg_alpha=1e-09, score=0.990750, total= 3.2min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 11.4min remaining:    0.0s
# [CV] reg_alpha=1e-09 .................................................
# [CV] .................. reg_alpha=1e-09, score=0.990350, total= 3.3min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 15.2min remaining:    0.0s
# [CV] reg_alpha=1e-09 .................................................
# [CV] .................. reg_alpha=1e-09, score=0.990900, total= 3.2min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 18.9min remaining:    0.0s
# [CV] reg_alpha=1e-07 .................................................
# [CV] .................. reg_alpha=1e-07, score=0.991525, total= 3.2min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 22.5min remaining:    0.0s
# [CV] reg_alpha=1e-07 .................................................
# [CV] .................. reg_alpha=1e-07, score=0.990400, total= 3.2min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 26.3min remaining:    0.0s
# [CV] reg_alpha=1e-07 .................................................
# [CV] .................. reg_alpha=1e-07, score=0.990750, total= 3.2min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 30.0min remaining:    0.0s
# [CV] reg_alpha=1e-07 .................................................
# [CV] .................. reg_alpha=1e-07, score=0.990350, total= 3.1min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 33.6min remaining:    0.0s
# [CV] reg_alpha=1e-07 .................................................
# [CV] .................. reg_alpha=1e-07, score=0.990900, total= 3.1min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 37.3min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.991550, total= 3.2min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 41.0min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990550, total= 3.2min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 44.7min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990575, total= 3.2min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 48.4min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990375, total= 3.2min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 52.0min remaining:    0.0s
# [CV] reg_alpha=1e-05 .................................................
# [CV] .................. reg_alpha=1e-05, score=0.990750, total= 3.2min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 55.7min remaining:    0.0s
# [CV] reg_alpha=0.001 .................................................
# [CV] .................. reg_alpha=0.001, score=0.991425, total= 3.1min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 59.4min remaining:    0.0s
# [CV] reg_alpha=0.001 .................................................
# [CV] .................. reg_alpha=0.001, score=0.990500, total= 3.2min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 63.1min remaining:    0.0s
# [CV] reg_alpha=0.001 .................................................
# [CV] .................. reg_alpha=0.001, score=0.990675, total= 3.2min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 66.8min remaining:    0.0s
# [CV] reg_alpha=0.001 .................................................
# [CV] .................. reg_alpha=0.001, score=0.990500, total= 3.1min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 70.4min remaining:    0.0s
# [CV] reg_alpha=0.001 .................................................
# [CV] .................. reg_alpha=0.001, score=0.990700, total= 3.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 74.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 74.1min finished
# [mean: 0.99079, std: 0.00042, params: {'reg_alpha': 1e-07},
#  mean: 0.99076, std: 0.00041, params: {'reg_alpha': 1e-05},
#  mean: 0.99076, std: 0.00034, params: {'reg_alpha': 0.001},
#  mean: 0.99074, std: 0.00048, params: {'reg_alpha': 1e-09}]

# %% [markdown]
# Next we focus on __reg_lambda__.

# %%
xgb = XGBClassifier(**gscv7.best_estimator_.get_params())
params = {'reg_lambda':[1e-5, 1e-2, 0, 0.1, 1, 100],
          
        }

gscv8 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv8.fit(X_train,y_train)
s = gscv8.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991575, total= 3.7min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.5min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991050, total= 3.7min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.0min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.990850, total= 3.8min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 13.6min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991500, total= 3.7min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 18.1min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991150, total= 3.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 22.6min remaining:    0.0s
# [CV] reg_lambda=0.01 .................................................
# [CV] .................. reg_lambda=0.01, score=0.991575, total= 3.3min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 26.4min remaining:    0.0s
# [CV] reg_lambda=0.01 .................................................
# [CV] .................. reg_lambda=0.01, score=0.991125, total= 3.3min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 30.3min remaining:    0.0s
# [CV] reg_lambda=0.01 .................................................
# [CV] .................. reg_lambda=0.01, score=0.990875, total= 3.3min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 34.1min remaining:    0.0s
# [CV] reg_lambda=0.01 .................................................
# [CV] .................. reg_lambda=0.01, score=0.991075, total= 3.3min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 38.0min remaining:    0.0s
# [CV] reg_lambda=0.01 .................................................
# [CV] .................. reg_lambda=0.01, score=0.991000, total= 3.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 41.8min remaining:    0.0s
# [CV] reg_lambda=0 ....................................................
# [CV] ..................... reg_lambda=0, score=0.991725, total= 3.9min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 46.7min remaining:    0.0s
# [CV] reg_lambda=0 ....................................................
# [CV] ..................... reg_lambda=0, score=0.990900, total= 3.8min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 51.4min remaining:    0.0s
# [CV] reg_lambda=0 ....................................................
# [CV] ..................... reg_lambda=0, score=0.990850, total= 3.8min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 56.1min remaining:    0.0s
# [CV] reg_lambda=0 ....................................................
# [CV] ..................... reg_lambda=0, score=0.991275, total= 3.8min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 60.9min remaining:    0.0s
# [CV] reg_lambda=0 ....................................................
# [CV] ..................... reg_lambda=0, score=0.991200, total= 3.9min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 65.6min remaining:    0.0s
# [CV] reg_lambda=0.1 ..................................................
# [CV] ................... reg_lambda=0.1, score=0.991775, total= 3.2min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 69.4min remaining:    0.0s
# [CV] reg_lambda=0.1 ..................................................
# [CV] ................... reg_lambda=0.1, score=0.990875, total= 3.2min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 73.2min remaining:    0.0s
# [CV] reg_lambda=0.1 ..................................................
# [CV] ................... reg_lambda=0.1, score=0.991050, total= 3.2min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 76.9min remaining:    0.0s
# [CV] reg_lambda=0.1 ..................................................
# [CV] ................... reg_lambda=0.1, score=0.990925, total= 3.2min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 80.6min remaining:    0.0s
# [CV] reg_lambda=0.1 ..................................................
# [CV] ................... reg_lambda=0.1, score=0.991400, total= 3.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 84.3min remaining:    0.0s
# [CV] reg_lambda=1 ....................................................
# [CV] ..................... reg_lambda=1, score=0.991525, total= 3.1min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 88.0min remaining:    0.0s
# [CV] reg_lambda=1 ....................................................
# [CV] ..................... reg_lambda=1, score=0.990400, total= 3.3min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 91.9min remaining:    0.0s
# [CV] reg_lambda=1 ....................................................
# [CV] ..................... reg_lambda=1, score=0.990750, total= 3.2min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 95.6min remaining:    0.0s
# [CV] reg_lambda=1 ....................................................
# [CV] ..................... reg_lambda=1, score=0.990350, total= 3.1min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 99.2min remaining:    0.0s
# [CV] reg_lambda=1 ....................................................
# [CV] ..................... reg_lambda=1, score=0.990900, total= 3.2min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 102.9min remaining:    0.0s
# [CV] reg_lambda=100 ..................................................
# [CV] ................... reg_lambda=100, score=0.946975, total= 2.5min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 105.8min remaining:    0.0s
# [CV] reg_lambda=100 ..................................................
# [CV] ................... reg_lambda=100, score=0.946875, total= 2.5min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 108.6min remaining:    0.0s
# [CV] reg_lambda=100 ..................................................
# [CV] ................... reg_lambda=100, score=0.944975, total= 2.6min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 111.6min remaining:    0.0s
# [CV] reg_lambda=100 ..................................................
# [CV] ................... reg_lambda=100, score=0.942525, total= 2.5min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 114.5min remaining:    0.0s
# [CV] reg_lambda=100 ..................................................
# [CV] ................... reg_lambda=100, score=0.945250, total= 2.5min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 117.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 117.3min finished
# [mean: 0.99123, std: 0.00027, params: {'reg_lambda': 1e-05},
#  mean: 0.99121, std: 0.00034, params: {'reg_lambda': 0.1},
#  mean: 0.99119, std: 0.00031, params: {'reg_lambda': 0},
#  mean: 0.99113, std: 0.00024, params: {'reg_lambda': 0.01},
#  mean: 0.99079, std: 0.00042, params: {'reg_lambda': 1},
#  mean: 0.94532, std: 0.00162, params: {'reg_lambda': 100}]

# %% [markdown]
# As well as in reg_alpha we've got the extreme value of 1e-05 so we do more searching.

# %%
xgb = XGBClassifier(**gscv8.best_estimator_.get_params())
params = {'reg_lambda':[1e-9, 1e-7, 1e-5, 1e-3]
          
        }

gscv9 = GridSearchCV(param_grid=params, estimator=xgb,cv=5, verbose=100)
gscv9.fit(X_train,y_train)
s = gscv9.grid_scores_.copy()
s.sort(key= lambda x: x[1],reverse=True)
s
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] reg_lambda=1e-09 ................................................
# [CV] ................. reg_lambda=1e-09, score=0.991825, total= 4.5min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.4min remaining:    0.0s
# [CV] reg_lambda=1e-09 ................................................
# [CV] ................. reg_lambda=1e-09, score=0.990975, total= 3.8min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.1min remaining:    0.0s
# [CV] reg_lambda=1e-09 ................................................
# [CV] ................. reg_lambda=1e-09, score=0.990950, total= 3.8min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 14.7min remaining:    0.0s
# [CV] reg_lambda=1e-09 ................................................
# [CV] ................. reg_lambda=1e-09, score=0.991125, total= 3.8min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 19.4min remaining:    0.0s
# [CV] reg_lambda=1e-09 ................................................
# [CV] ................. reg_lambda=1e-09, score=0.991300, total= 3.8min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 24.0min remaining:    0.0s
# [CV] reg_lambda=1e-07 ................................................
# [CV] ................. reg_lambda=1e-07, score=0.991875, total= 3.8min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 28.7min remaining:    0.0s
# [CV] reg_lambda=1e-07 ................................................
# [CV] ................. reg_lambda=1e-07, score=0.990825, total= 3.8min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 33.3min remaining:    0.0s
# [CV] reg_lambda=1e-07 ................................................
# [CV] ................. reg_lambda=1e-07, score=0.991025, total= 3.8min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 37.9min remaining:    0.0s
# [CV] reg_lambda=1e-07 ................................................
# [CV] ................. reg_lambda=1e-07, score=0.991225, total= 3.8min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 42.5min remaining:    0.0s
# [CV] reg_lambda=1e-07 ................................................
# [CV] ................. reg_lambda=1e-07, score=0.991100, total= 4.0min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 47.4min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991575, total= 3.6min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 51.8min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991050, total= 3.6min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 56.2min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.990850, total= 3.6min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 60.6min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991500, total= 3.6min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 65.0min remaining:    0.0s
# [CV] reg_lambda=1e-05 ................................................
# [CV] ................. reg_lambda=1e-05, score=0.991150, total= 3.6min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 69.4min remaining:    0.0s
# [CV] reg_lambda=0.001 ................................................
# [CV] ................. reg_lambda=0.001, score=0.992000, total= 3.3min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 73.2min remaining:    0.0s
# [CV] reg_lambda=0.001 ................................................
# [CV] ................. reg_lambda=0.001, score=0.991275, total= 3.3min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 77.1min remaining:    0.0s
# [CV] reg_lambda=0.001 ................................................
# [CV] ................. reg_lambda=0.001, score=0.991050, total= 3.3min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 80.9min remaining:    0.0s
# [CV] reg_lambda=0.001 ................................................
# [CV] ................. reg_lambda=0.001, score=0.991200, total= 3.3min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 84.9min remaining:    0.0s
# [CV] reg_lambda=0.001 ................................................
# [CV] ................. reg_lambda=0.001, score=0.991125, total= 3.3min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 88.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 88.8min finished
# [mean: 0.99133, std: 0.00034, params: {'reg_lambda': 0.001},
#  mean: 0.99123, std: 0.00032, params: {'reg_lambda': 1e-09},
#  mean: 0.99123, std: 0.00027, params: {'reg_lambda': 1e-05},
#  mean: 0.99121, std: 0.00036, params: {'reg_lambda': 1e-07}]

# %% [markdown]
# We see that __creg_alpha__: 1e-05 and __reg_lambda__: 0.001 were the most optimum values.
#
# Finally we've achieved our optimal XGBoost algorithm.

# %%
print(gscv9.best_estimator_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.6, gamma=0.0, learning_rate=0.1,
#        max_delta_step=0, max_depth=50, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='multi:softprob', random_state=0, reg_alpha=1e-07,
#        reg_lambda=0.001, scale_pos_weight=1, seed=None, silent=True,
#        subsample=0.9)

# %% [markdown]
# Next we should lower the __learning rate__ to 0.01 and add more __trees__ - 1000.

# %%
best_model = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
                           colsample_bytree=0.6, gamma=0.0, learning_rate=0.01,
                           max_delta_step=0, max_depth=50, min_child_weight=1, missing=None,
                           n_estimators=1000, n_jobs=1, nthread=None,
                           objective='multi:softprob', random_state=0, reg_alpha=1e-07,
                           reg_lambda=0.001, scale_pos_weight=1, seed=None, silent=True,
                           subsample=0.9)

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_train)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_train, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 100.00%

# %%
y_pred = best_model.predict(X_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 87.67%

# %% [markdown]
# A score of over 87%.
#
# Summarizing our tuned XGBoost algorithm got the best score for training and test datasets.

# %% [markdown]
# ## 2.Test dataset
#
# ### 2.1 Data analysis
#
# Test area consists of 46 973 LiDAR points located over 9 896 square meters.
#
# <img src='img/Zakres2_2d.jpg' width="80%">
# <img src='img/Zakres2_3d.jpg' width="80%">

# %%
t_area = pd.read_csv('data/01.Test_Area.csv', header=0, delimiter=' ')

# %%
t_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46973 entries, 0 to 46972
# Data columns (total 13 columns):
# X                    46973 non-null float64
# Y                    46973 non-null float64
# Z                    46973 non-null float64
# R                    46973 non-null int64
# G                    46973 non-null int64
# B                    46973 non-null int64
# PointSourceId        46973 non-null float64
# ScanAngleRank        46973 non-null float64
# ScanDirectionFlag    46973 non-null float64
# NumberOfReturns      46973 non-null float64
# ReturnNumber         46973 non-null float64
# Intensity            46973 non-null float64
# Classification       46973 non-null float64
# dtypes: float64(10), int64(3)
# memory usage: 4.7 MB

# %%
t_area.isnull().sum()
# Out:
# X                    0
# Y                    0
# Z                    0
# R                    0
# G                    0
# B                    0
# PointSourceId        0
# ScanAngleRank        0
# ScanDirectionFlag    0
# NumberOfReturns      0
# ReturnNumber         0
# Intensity            0
# Classification       0
# dtype: int64

# %% [markdown]
# We can see that in test area there are also only numerical features and that there are no null values within all data, so we can proceed with further analysis.

# %%
t_area.nunique()
# Out:
# X                    4487
# Y                    1544
# Z                    1544
# R                     229
# G                     221
# B                     224
# PointSourceId           1
# ScanAngleRank          11
# ScanDirectionFlag       1
# NumberOfReturns         4
# ReturnNumber            4
# Intensity             136
# Classification          7
# dtype: int64

# %%
t_area.describe()
# Out:
#                    X              Y             Z             R             G  \
# count   46973.000000   46973.000000  46973.000000  46973.000000  46973.000000
# mean   484499.657893  676695.825493     51.604332     94.718668    104.116897
# std        37.549904      22.437810      2.714440     43.486938     36.612584
# min    484414.687500  676647.125000     48.160000     24.000000     34.000000
# 25%    484477.000000  676677.250000     50.189999     58.000000     73.000000
# 50%    484506.406250  676698.250000     50.490002     88.000000    106.000000
# 75%    484530.875000  676714.187500     51.090000    129.000000    129.000000
# max    484559.031250  676744.000000     67.779999    253.000000    255.000000
#
#                   B  PointSourceId  ScanAngleRank  ScanDirectionFlag  \
# count  46973.000000        46973.0   46973.000000            46973.0
# mean      94.983373          102.0       6.878143                1.0
# std       34.155992            0.0       2.781233                0.0
# min       32.000000          102.0       1.000000                1.0
# 25%       68.000000          102.0       5.000000                1.0
# 50%       91.000000          102.0       7.000000                1.0
# 75%      116.000000          102.0       9.000000                1.0
# max      255.000000          102.0      11.000000                1.0
#
#        NumberOfReturns  ReturnNumber     Intensity  Classification
# count     46973.000000  46973.000000  46973.000000    46973.000000
# mean          1.164265      1.081707     72.090520        2.771103
# std           0.411827      0.292560     32.275862        1.498565
# min           1.000000      1.000000      9.000000        0.000000
# 25%           1.000000      1.000000     49.000000        2.000000
# 50%           1.000000      1.000000     72.000000        2.000000
# 75%           1.000000      1.000000     96.000000        2.000000
# max           4.000000      4.000000    176.000000        7.000000

# %%
t_area = t_area.drop(['PointSourceId', 'ScanDirectionFlag', 'X', 'Y'], axis = 1)

# %%
X2 = t_area.iloc[:,0:8]
y2 = t_area.iloc[:,8]

# %%
X2.head(5)
# Out:
#            Z   R    G    B  ScanAngleRank  NumberOfReturns  ReturnNumber  \
# 0  50.759998  83  116   99            6.0              1.0           1.0
# 1  50.750000  91  125  105            6.0              1.0           1.0
# 2  50.680000  88  119  102            6.0              1.0           1.0
# 3  50.689999  89  120  104            6.0              1.0           1.0
# 4  50.700001  77  110   93            6.0              1.0           1.0
#
#    Intensity
# 0       70.0
# 1       73.0
# 2       70.0
# 3       60.0
# 4       71.0

# %%
y2.head(5)
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: Classification, dtype: float64

# %%
np.unique(t_area.Classification, return_counts=True)
# Out:
# (array([0., 2., 3., 4., 5., 6., 7.]),
#  array([  635, 34745,   999,   768,  4360,  5454,    12]))

# %%
plt.hist(t_area.Classification, color = 'skyblue')

plt.title('LiDAR points in each class')

plt.show()

# %%
X2 = mm.fit_transform(X2) #we scale our data as in the first train/test area

# %% [markdown]
# ### 2.2 XGBoost - default

# %%
y2_pred = model_xgb.predict(X2)
predictions2 = [round(value) for value in y2_pred]
accuracy = accuracy_score(y2, predictions2)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 47.78%

# %% [markdown]
# ### 2.3 XGBoost - tuned

# %%
y2_pred = best_model.predict(X2)
predictions2 = [round(value) for value in y2_pred]
accuracy = accuracy_score(y2, predictions2)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 54.90%

# %% [markdown]
# Only 54% ! So summarizing accuracies on X2, y2 test areas were really low in comparisson to X_test and y_test data from train/test area.
#
# We will split our test area dataset to train, test data to see how our optimized XGBoost model works fitted on X2_train, y2_train data.

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.33)
X2_train = mm.fit_transform(X2_train)
X2_test = mm.fit_transform(X2_test)

# %%
best_model = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
                           colsample_bytree=0.6, gamma=0.0, learning_rate=0.01,
                           max_delta_step=0, max_depth=50, min_child_weight=1, missing=None,
                           n_estimators=1000, n_jobs=1, nthread=None,
                           objective='multi:softprob', random_state=0, reg_alpha=1e-07,
                           reg_lambda=0.001, scale_pos_weight=1, seed=None, silent=True,
                           subsample=0.9)

best_model.fit(X2_train, y2_train)
y2_pred = best_model.predict(X2_train)
predictions = [round(value) for value in y2_pred]
accuracy = accuracy_score(y2_train, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 100.00%

# %% [markdown]
# We have achieved perfect score on train test area.

# %%
y2_pred = best_model.predict(X2_test)
predictions = [round(value) for value in y2_pred]
accuracy = accuracy_score(y2_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))t
# Out:
# Accuracy: 94.99%

# %% [markdown]
# And almost 95% on test dataset! In conclusion two factors maybe to blame here.
#
# First the chosen features were not optimal and we should try a pick other than __Univariate Selection__.
#
# The second is that we only had one train/test area and our test area may have varied too much to achieve good result. With better hardware capabilities we could have chosen over a dozen of train/test areas and fit combined data into our algorithm.
#
# To wrap things up there will be consecutive notebook __"02. XGBoost for Aerial LiDAR Data Classification with extended training dataset"__ where __XGBoost__ algorithm  will be trained an fit on __6 training areas__.
